# %%
# 1. Mount Drive (Hanya perlu sekali per sesi)
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install transformers torch sentencepiece

# %%
model_path = "/content/drive/MyDrive/ML_Project/indobert-sentiment-model"

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification

tokenizer = AutoTokenizer.from_pretrained(model_path)
model = AutoModelForSequenceClassification.from_pretrained(model_path)
# Out:
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]

# %%
# !pip install bertopic
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.7/154.7 kB 9.3 MB/s eta 0:00:00
# ...

# %%
from bertopic import BERTopic
import pandas as pd

path = '/content/drive/My Drive/CSV/reviews_cleaned.csv'
df = pd.read_csv(path)

# 3. Inisialisasi BERTopic (bahasa Indonesia)
topic_model = BERTopic(language="indonesian", calculate_probabilities=True, verbose=True)

# 4. Fit Model ke teks review
topics, probs = topic_model.fit_transform(df['content_cleaned'].astype(str))

# 5. Lihat Topik yang Terbentuk
topic_info = topic_model.get_topic_info()
print(topic_info.head(10))

# 6. Visualisasikan (Ini sangat keren untuk ditaruh di portofolio!)
topic_model.visualize_topics()
# Out:
# 2026-05-16 04:39:25,229 - BERTopic - Embedding - Transforming documents to embeddings.
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/645 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/471M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# ...

# %%
# Mendapatkan info topik (Topic, Count, Name, Representation)
topic_info = topic_model.get_topic_info()
topic_info
# Out:
#     Topic  Count                                  Name  \
# 0      -1     24                -1_nan_terbaik_the_sgt
# 1       0    233                   0_dana_saya_di_bisa
# 2       1     40          1_bagus_baguss_nice_sempurna
# 3       2     35            2_bagus_sangat_baik_sekali
# 4       3     31  3_membantu_sangat_terimakasih_sangai
# 5       4     25        4_mantap_tahap_posting_aktivin
# 6       5     24       5_baik_berbicara_pme_bermanfaat
# 7       6     20             6_ok_oke_pokonya_membantu
# 8       7     13        7_puas_memuaskan_sangat_sukses
# 9       8     13             8_bgus_mantab_bug_plyanan
# 10      9     12               9_good_walaupun_apl_job
# 11     10     11                10_keren_top_cepat_boy
#
#                                        Representation  \
# 0   [nan, terbaik, the, sgt, best, eka, ajiiiiib, ...
# 1   [dana, saya, di, bisa, tidak, cicil, dan, apli...
# 2   [bagus, baguss, nice, sempurna, sekali, baik, ...
# ...

# %%
# Simpan ke folder data proyekmu
topic_info.to_csv('/content/drive/My Drive/CSV/Dana_bertopic_results.csv', index=False)

print("✅ Informasi topik telah disimpan!")
# Out:
# ✅ Informasi topik telah disimpan!

# %%
df['Topic'] = topics
df['Topic']
# Out:
# 0      0
# 1      9
# 2      1
# 3      0
# 4      0
#       ..
# 476    0
# 477    1
# 478    2
# 479    8
# 480    0
# Name: Topic, Length: 481, dtype: int64

# %%
df.head(2)
# Out:
#                                      content_cleaned  label Sentiment_Label  \
# 0  dana cicil tidak bisa di pake padahal udah bay...    0.0       Negatif 😡
# 1                                               good    1.0       Positif 😊
#
#    Topic
# 0      0
# 1      9

# %%
# Jika label 1 = Positif, 0 = Negatif
df['Sentiment_Label'] = df['label'].map({1: 'Positif 😊', 0: 'Negatif 😡'})
df['Sentiment_Label']
# Out:
# 0      Negatif 😡
# 1      Positif 😊
# 2      Positif 😊
# 3      Negatif 😡
# 4      Positif 😊
#          ...
# 476    Positif 😊
# 477    Positif 😊
# 478    Positif 😊
# 479    Positif 😊
# 480    Negatif 😡
# Name: Sentiment_Label, Length: 481, dtype: object

# %%
#filter topik -1 (outlier) agar fokus
df_filtered = df[df['Topic'] != -1]

# %%
# 3. Buat pivot table: Baris = Topik, Kolom = Sentimen
sentiment_per_topic = df_filtered.groupby(['Topic', 'Sentiment_Label']).size().unstack(fill_value=0)

# 4. Ambil nama asli topiknya (bukan cuma angka)
topic_names = topic_model.get_topic_info()[['Topic', 'Name']]
sentiment_per_topic = sentiment_per_topic.merge(topic_names, on='Topic')

# %%
# Simpan ke folder data proyekmu
sentiment_per_topic.to_csv('/content/drive/My Drive/CSV/DANA_sentiment_per_topic.csv', index=False)

print("✅ Informasi topik telah disimpan!")
# Out:
# ✅ Informasi topik telah disimpan!
